# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os

import statsmodels.formula.api as smf

# %% [markdown]
# # Load data

# %%
data_path = "feature_with_ecg_df_test_lead2.csv"
data_df = pd.read_csv(data_path)
data_df
# Out:
#         cycle_ID  patient_ID  interval_ID  block_ID  channel_ID  segment_ID  \
# 0              1      771495      8748755         1           2           1
# 1              2      771495      8748755         1           2           1
# 2              3      771495      8748755         1           2           1
# 3              4      771495      8748755         1           2           1
# 4              5      771495      8748755         1           2           1
# ...          ...         ...          ...       ...         ...         ...
# 114407       308      536886      8748726         1           2           2
# 114408       309      536886      8748726         1           2           2
# 114409       310      536886      8748726         1           2           2
# 114410       311      536886      8748726         1           2           2
# 114411       312      536886      8748726         1           2           2
#
# ...

# %% [markdown]
# # Load Model

# %%
from src.utils.ECG_data_loading import *

# %%
from torch.utils.data import DataLoader
from src.methods.supervised_1d import SupervisedModel_1D
from src.models.CLOCS_1D import cnn_network_contrastive
import torch.nn as nn
from pathlib import Path
from src.utils.metrics import accuracy_at_k, weighted_mean, AUROC
import time

# %%
embedding_dim = 16
# embedding_dim = 1
model = cnn_network_contrastive(zero_init_residual=None, embedding_dim=embedding_dim,
                   stride=2, c4_multiplier=3)
# remove fc layer
model.fc = nn.Identity()
# Out:
# 2 0.1 0.1 0.1 1 16 CLOCS

# %%
# build paths
## embedding dim = 16
ckpt_dir = Path("trained_models/linear/wxjvsino")
ckpt_path = [ckpt_dir / ckpt for ckpt in os.listdir(ckpt_dir) if ckpt.endswith("val_auroc=0.9236.ckpt")][0]
## embedding dim = 1
# ckpt_dir = Path("trained_models/linear/igtzgoky")
# ckpt_path = [ckpt_dir / ckpt for ckpt in os.listdir(ckpt_dir) if ckpt.endswith("val_auroc=0.9736.ckpt")][0]

args_path = ckpt_dir / "args.json"
print(f"args_path: {args_path}")
print(f"ckpt_path: {ckpt_path}")

# load arguments
with open(args_path) as f:
    method_args = json.load(f)
print(f"method_args {type(method_args)}: {method_args}")
# build the model
model.pretrained_occlusion_model_dict = None
method_args["backbone"] = model
model_loaded = SupervisedModel_1D.load_from_checkpoint(
    ckpt_path, strict=False, **method_args
)
# Out:
# args_path: trained_models/linear/wxjvsino/args.json
# ckpt_path: trained_models/linear/wxjvsino/None-wxjvsino-epoch=21-val_auroc=0.9236.ckpt
# ...

# %% [markdown]
# # Run test

# %%
feature_with_ecg_df_test_single_lead = data_df
test_dataset = ECG_classification_dataset_with_peak_features(feature_with_ecg_df_test_single_lead,
                                                                     shift_signal=False,
                                                                     shift_amount=0,
                                                                     normalize_signal=True,
                                                                     ecg_resampling_length_target=300)
test_loader = DataLoader(
    test_dataset, batch_size=128, num_workers=1, shuffle=False, drop_last=False
)
for i, data in enumerate(test_loader):
    print(i, len(data))
    break
# Out:
# 0 2

# %%
X_all_list = []
X_embedding_all_list = []
y_true_all_list = []
X_logits_all_list = []

model_loaded.eval()
test_auroc = AUROC(pos_label=1)
softmax = torch.nn.Softmax(dim=1)

for i, data in enumerate(test_loader):
    print(f"Batch {i} / {len(test_loader)}")
    X, y = data
    X_all_list.append(X)
    X_embedding = model_loaded.backbone(X)
    X_logits = model_loaded.classifier(X_embedding)
#     print(X_embedding.shape, y.shape)
#     print(y)
#     print(X_logits)
    X_embedding_all_list.append(X_embedding)
    y_true_all_list.append(y)
    X_logits_all_list.append(X_logits)
    
    scores = softmax(X_logits)[:, 1].detach()
    test_auroc.update(scores, y.detach())
#     break
    
test_auroc_val = test_auroc.compute()
test_auroc.reset()
print(f"test_auroc_val = {test_auroc_val:.4f}")
# Out:
# Batch 0 / 894
# Batch 1 / 894
# Batch 2 / 894
# Batch 3 / 894
# Batch 4 / 894
# Batch 5 / 894
# Batch 6 / 894
# Batch 7 / 894
# Batch 8 / 894
# Batch 9 / 894
# Batch 10 / 894
# Batch 11 / 894
# Batch 12 / 894
# Batch 13 / 894
# Batch 14 / 894
# Batch 15 / 894
# Batch 16 / 894
# Batch 17 / 894
# Batch 18 / 894
# Batch 19 / 894
# Batch 20 / 894
# Batch 21 / 894
# Batch 22 / 894
# Batch 23 / 894
# Batch 24 / 894
# Batch 25 / 894
# Batch 26 / 894
# Batch 27 / 894
# Batch 28 / 894
# Batch 29 / 894
# Batch 30 / 894
# Batch 31 / 894
# Batch 32 / 894
# Batch 33 / 894
# Batch 34 / 894
# Batch 35 / 894
# Batch 36 / 894
# Batch 37 / 894
# Batch 38 / 894
# Batch 39 / 894
# Batch 40 / 894
# Batch 41 / 894
# Batch 42 / 894
# Batch 43 / 894
# Batch 44 / 894
# Batch 45 / 894
# Batch 46 / 894
# Batch 47 / 894
# Batch 48 / 894
# Batch 49 / 894
# Batch 50 / 894
# Batch 51 / 894
# Batch 52 / 894
# Batch 53 / 894
# Batch 54 / 894
# Batch 55 / 894
# Batch 56 / 894
# Batch 57 / 894
# Batch 58 / 894
# ...

# %%
X_all = torch.cat(X_all_list, dim=0)
y_true_all = torch.cat(y_true_all_list, dim=0)
X_embedding_all = torch.cat(X_embedding_all_list, dim=0)
X_embedding_all_np = X_embedding_all.detach().numpy()
y_true_all_np = y_true_all.detach().numpy()
X_all.shape, y_true_all.shape, X_embedding_all.shape
# Out:
# (torch.Size([114412, 1, 300]), torch.Size([114412]), torch.Size([114412, 16]))

# %% [markdown]
# ## Embedding dim = 1

# %%
model_loaded.classifier
# Out:
# Linear(in_features=1, out_features=2, bias=True)

# %%
W = None
b = None
for i, params in enumerate(model_loaded.classifier.parameters()):
    print(i, params.shape, params)
    if i == 0:
        W = params
    elif i == 1:
        b = params
# Out:
# 0 torch.Size([2, 1]) Parameter containing:
# tensor([[-0.3337],
#         [ 1.4288]], requires_grad=True)
# 1 torch.Size([2]) Parameter containing:
# tensor([1.0869, 0.5672], requires_grad=True)

# %%
# -0.3337x + 1.0869 = 1.4288x + 0.5672
decision_threhold_50 = (b[0] - b[1]) / (W.ravel()[1] - W.ravel()[0])
decision_threhold_50
# Out:
# tensor(0.2949, grad_fn=<DivBackward0>)

# %%
decision_threhold_50 * W.ravel()[0] + b[0], decision_threhold_50 * W.ravel()[1] + b[1]
# Out:
# (tensor(0.9885, grad_fn=<AddBackward0>),
#  tensor(0.9885, grad_fn=<AddBackward0>))

# %%
plt.figure(figsize=(10, 10))
plt.scatter(np.arange(len(X_embedding_all_np)), X_embedding_all_np, c=y_true_all_np, cmap="rainbow", alpha=0.1)
plt.gca().axhline(decision_threhold_50.detach().numpy(), color="#FF0000")

# %% [markdown]
# # Embedding Visualization

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

# %%
import numpy as np
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
X_embedding_all_np = X_embedding_all.detach().numpy()
pca.fit(X_embedding_all_np.T)
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
# Out:
# [9.9310035e-01 2.6282212e-03 1.3222925e-03 7.8430783e-04 4.6500741e-04
#  3.8224607e-04 3.0423931e-04 2.0983820e-04 1.9487580e-04 1.7443897e-04]
# [2107.9536    108.441475   76.918045   59.239006   45.613605   41.35576
#    36.895393   30.64127    29.528639   27.937416]

# %%
plt.plot(pca.explained_variance_ratio_)

# %%
pca.components_.shape
# Out:
# (10, 114412)

# %%
pca.components_[:2, :]

# %%
y_true_all_np = y_true_all.detach().numpy()

# %%
import matplotlib.cm as cm
color_list = [cm.tab10(ele) for ele in y_true_all_np]

# %%
sns.set(style="white")
plt.figure(figsize=(9, 9))
plt.scatter(pca.components_[0, :], pca.components_[1, :], c=color_list, alpha=0.3)

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=pca.components_[0, :], 
    ys=pca.components_[1, :], 
    zs=pca.components_[2, :], 
    c=color_list, alpha=0.3
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
plt.show()

# %% [markdown]
# ## t-SNE

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=1000)
tsne_results = tsne.fit_transform(X_embedding_all_np)
# Out:
# /Users/yj31/opt/anaconda3/envs/jpy3.7/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /Users/yj31/opt/anaconda3/envs/jpy3.7/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 114412 samples in 0.002s...
# [t-SNE] Computed neighbors for 114412 samples in 221.476s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 114412
# [t-SNE] Computed conditional probabilities for sample 2000 / 114412
# [t-SNE] Computed conditional probabilities for sample 3000 / 114412
# [t-SNE] Computed conditional probabilities for sample 4000 / 114412
# [t-SNE] Computed conditional probabilities for sample 5000 / 114412
# [t-SNE] Computed conditional probabilities for sample 6000 / 114412
# ...

# %%
print(tsne_results.shape)
# Out:
# (114412, 2)

# %%
sns.set(style="white")
plt.figure(figsize=(9, 9))
plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=color_list, alpha=0.1)

# %% [markdown]
# # Sort Embeddings by Each Dimension

# %%
X_embedding_all_sorted_dict = {}
X_embedding_all_sinds_dict = {}

# %%
embedding_idx = 0
_, X_embedding_all_sinds_dict[embedding_idx] \
    = torch.sort(X_embedding_all[:, embedding_idx])
X_embedding_all_sorted_dict[embedding_idx] = X_embedding_all[X_embedding_all_sinds_dict[embedding_idx]]

# %%
X_all_sorted = X_all[X_embedding_all_sinds_dict[embedding_idx]]
y_all_sorted = y_true_all[X_embedding_all_sinds_dict[embedding_idx]]

# %% [markdown]
# ## Embedding dim = 1

# %%
X_embedding_all_np_sorted = X_embedding_all_sorted_dict[embedding_idx].detach().numpy()
y_true_all_np_sorted = y_all_sorted.detach().numpy()
plt.figure(figsize=(10, 10))
plt.scatter(np.arange(len(X_embedding_all_np_sorted)), X_embedding_all_np_sorted,
            c=y_true_all_np_sorted, cmap="rainbow", alpha=0.1)
plt.gca().axhline(decision_threhold_50.detach().numpy(), color="#FF0000")

# %%
plt.figure(figsize=(10, 10))

markers = ["s","o"]
colors = [cm.tab10(0), cm.tab10(3)]
for i, c in enumerate(np.unique(y_true_all_np_sorted)):
    plt.scatter(np.arange(len(X_embedding_all_np_sorted))[y_true_all_np_sorted==c],
                X_embedding_all_np_sorted[y_true_all_np_sorted==c],
                color=colors[i], marker=markers[i],
                cmap="rainbow", alpha=0.01)
plt.gca().axhline(decision_threhold_50.detach().numpy(), color="#FF0000")

# %%
img_folder = f"ecg_sorted_by_embedding{embedding_idx}"
os.makedirs(os.path.join(ckpt_dir, img_folder), exist_ok=True)
label_dict = {0: "SINUS", 1: "JET"}
color_dict = {0: "#0000FF", 1: "#FF0000"}
st = time.time()
show_int = len(X_all_sorted) // 100
for j, ecg in enumerate(X_all_sorted):
    if j % show_int == 0:
        print(f"{j} / {len(X_all_sorted)}")
        name = f"em{embedding_idx} ecg{j}"
        y_label = int(y_all_sorted[j].numpy())
        plt.figure(figsize=(6, 3))
        plt.plot(ecg.ravel(), label=f"{name} - {label_dict[y_label]}", color=color_dict[y_label])
        plt.legend(loc="upper center")
        plt.savefig(os.path.join(ckpt_dir, img_folder, f"{name}.png"), dpi=25)
        plt.close()
#     if j >= 5:
#         break
# Out:
# 0 / 114412
# 1144 / 114412
# 2288 / 114412
# 3432 / 114412
# 4576 / 114412
# 5720 / 114412
# 6864 / 114412
# 8008 / 114412
# 9152 / 114412
# 10296 / 114412
# 11440 / 114412
# 12584 / 114412
# 13728 / 114412
# 14872 / 114412
# 16016 / 114412
# 17160 / 114412
# 18304 / 114412
# 19448 / 114412
# 20592 / 114412
# 21736 / 114412
# 22880 / 114412
# 24024 / 114412
# 25168 / 114412
# 26312 / 114412
# 27456 / 114412
# 28600 / 114412
# 29744 / 114412
# 30888 / 114412
# 32032 / 114412
# 33176 / 114412
# 34320 / 114412
# 35464 / 114412
# 36608 / 114412
# 37752 / 114412
# 38896 / 114412
# 40040 / 114412
# 41184 / 114412
# 42328 / 114412
# 43472 / 114412
# 44616 / 114412
# 45760 / 114412
# 46904 / 114412
# 48048 / 114412
# 49192 / 114412
# 50336 / 114412
# 51480 / 114412
# 52624 / 114412
# 53768 / 114412
# 54912 / 114412
# 56056 / 114412
# 57200 / 114412
# 58344 / 114412
# 59488 / 114412
# 60632 / 114412
# 61776 / 114412
# 62920 / 114412
# 64064 / 114412
# 65208 / 114412
# 66352 / 114412
# ...

# %% [markdown]
# ## Embedding dim = 16

# %%
for embedding_idx in range(X_embedding_all.shape[1]):
    # embedding_idx = 0
    _, X_embedding_all_sinds_dict[embedding_idx] \
        = torch.sort(X_embedding_all[:, embedding_idx])
    X_embedding_all_sorted_dict[embedding_idx] = X_embedding_all[X_embedding_all_sinds_dict[embedding_idx]]

# %%
nrow = 4
ncol = 4
label_dict = {0: "SINUS", 1: "JET"}
color_dict = {0: "#0000FF", 1: "#FF0000"}
sns.set(style="white")

top_k = -1
top_k = 1000

os.makedirs(os.path.join(ckpt_dir, img_folder), exist_ok=True)

st = time.time()
for j in range(len(y_true_all)):
    if j % show_int == 0:
        fig, axes = plt.subplots(nrow, ncol, figsize=(ncol * 6, nrow * 3))
        for embedding_idx in range(X_embedding_all.shape[1]):
            r = embedding_idx // ncol
            c = embedding_idx % ncol
            
            if top_k > 0:
                X_embedding_all_sinds = X_embedding_all_sinds_dict[embedding_idx][:top_k]
                img_folder = f"ecg_sorted_by_embedding_separately_top{top_k}"
                show_int = top_k // 100

            else:
                X_embedding_all_sinds = X_embedding_all_sinds_dict[embedding_idx]
                img_folder = f"ecg_sorted_by_embedding_separately"
                show_int = len(y_true_all) // 100


#             X_all_sorted = X_all[X_embedding_all_sinds_dict[embedding_idx]]
#             y_all_sorted = y_true_all[X_embedding_all_sinds_dict[embedding_idx]]

            ecg = X_all[X_embedding_all_sinds[j], ...]
            y_label = int(y_true_all[X_embedding_all_sinds[j]].numpy())
            
            print(f"{embedding_idx} / {X_embedding_all.shape[1]}, {j} / {len(y_true_all)}")
            name = f"em{embedding_idx} ecg{j}"
            ax = axes[r, c]
            ax.plot(ecg.ravel(), label=f"{name} - {label_dict[y_label]}", color=color_dict[y_label])
            ax.legend(loc="upper center")
            
        plt.tight_layout()
        plt.savefig(os.path.join(ckpt_dir, img_folder, f"ecg{j}.png"), dpi=25)
        plt.close()
#     if j >= 5:
#         break
# Out:
# 0 / 16, 0 / 114412
# 1 / 16, 0 / 114412
# 2 / 16, 0 / 114412
# 3 / 16, 0 / 114412
# 4 / 16, 0 / 114412
# 5 / 16, 0 / 114412
# 6 / 16, 0 / 114412
# 7 / 16, 0 / 114412
# 8 / 16, 0 / 114412
# 9 / 16, 0 / 114412
# 10 / 16, 0 / 114412
# 11 / 16, 0 / 114412
# 12 / 16, 0 / 114412
# 13 / 16, 0 / 114412
# 14 / 16, 0 / 114412
# 15 / 16, 0 / 114412
# 0 / 16, 10 / 114412
# 1 / 16, 10 / 114412
# 2 / 16, 10 / 114412
# 3 / 16, 10 / 114412
# 4 / 16, 10 / 114412
# 5 / 16, 10 / 114412
# 6 / 16, 10 / 114412
# 7 / 16, 10 / 114412
# 8 / 16, 10 / 114412
# 9 / 16, 10 / 114412
# 10 / 16, 10 / 114412
# 11 / 16, 10 / 114412
# 12 / 16, 10 / 114412
# 13 / 16, 10 / 114412
# 14 / 16, 10 / 114412
# 15 / 16, 10 / 114412
# 0 / 16, 20 / 114412
# 1 / 16, 20 / 114412
# 2 / 16, 20 / 114412
# 3 / 16, 20 / 114412
# 4 / 16, 20 / 114412
# 5 / 16, 20 / 114412
# 6 / 16, 20 / 114412
# 7 / 16, 20 / 114412
# 8 / 16, 20 / 114412
# 9 / 16, 20 / 114412
# 10 / 16, 20 / 114412
# 11 / 16, 20 / 114412
# 12 / 16, 20 / 114412
# ...

# %%
for embedding_idx in range(X_embedding_all.shape[1]):
    _, X_embedding_all_sinds_dict[embedding_idx] \
        = torch.sort(X_embedding_all[:, embedding_idx])
    X_embedding_all_sorted_dict[embedding_idx] = X_embedding_all[X_embedding_all_sinds_dict[embedding_idx]]

# %%
for embedding_idx in range(X_embedding_all.shape[1]):
    # embedding_idx = 0
    X_all_sorted = X_all[X_embedding_all_sinds_dict[embedding_idx]]
    y_all_sorted = y_true_all[X_embedding_all_sinds_dict[embedding_idx]]
    img_folder = f"ecg_sorted_by_embedding{embedding_idx}"
    os.makedirs(os.path.join(ckpt_dir, img_folder), exist_ok=True)
    label_dict = {0: "SINUS", 1: "JET"}
    color_dict = {0: "#0000FF", 1: "#FF0000"}
    st = time.time()
    show_int = len(X_all_sorted) // 100
    for j, ecg in enumerate(X_all_sorted):
        if j % show_int == 0:
            print(f"{embedding_idx} / {X_embedding_all.shape[1]}, {j} / {len(X_all_sorted)}")
            name = f"em{embedding_idx} ecg{j}"
            y_label = int(y_all_sorted[j].numpy())
            plt.figure(figsize=(6, 3))
            plt.plot(ecg.ravel(), label=f"{name} - {label_dict[y_label]}", color=color_dict[y_label])
            plt.legend(loc="upper center")
            plt.savefig(os.path.join(ckpt_dir, img_folder, f"{name}.png"), dpi=25)
            plt.close()
#     if j >= 5:
#         break
